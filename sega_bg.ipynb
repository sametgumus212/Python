# %% [markdown]
# <a href="https://colab.research.google.com/github/sametgumus212/Python/blob/master/sega_bg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
def headermenuitemfinder(link):
  category_array=[]
  b="/"
  lnk=""
  req = requests.get(link)
  soup = BeautifulSoup(req.content, "lxml")
  # title=soup.find("ul",attrs={"class":"navbar-nav"}).findAll('li')
  title=soup.findAll("a")#,attrs={"class":"main_nav__link"})
  s=0
  for i in title:
    
    j=i.get("href")
    if (s==16):
      break
    if (j.startswith("/category")):
      b=(i.get("href"))
      s+=1   
      lnk=("{}{}{}".format("https://www.segabg.com",b,"?page=1"))      
      category_array.append(lnk)
  return category_array

# %%
def page_count_finder(categories_link):
  s=1
  for i in range(1000):
    lnk=link[:-1]
    print("{}{}".format(lnk,s))
    if(s==5):
      break
    s+=1

# %%
def all_page_links(categories_links):
  All_pages_links=[]
  for i in categories_links:
    category_pages_count=is_exist(i,1)
    for j in range(len(category_pages_count)):
      All_pages_links.append("{}{}".format(categories_links[i-1],j+1))
      # print(All_pages_links)
  return All_pages_links

# %%
def all_page_links_creator(categories_links):
  # All_pages_link=[]
  p_link=""
  for i in range(len(categories_links)):# categories_links:
    category_pages_count=is_exist(categories_links[i],1)
    h=categories_links[i]
    for j in range(1,category_pages_count+1,1):
      p_link="{}{}".format(h[:-1],j)
      # All_pages_link.append(p_link)
      with open("sega_bg_all_links.txt", 'a') as file: 
        file.write(p_link+'\n')
  # return All_pages_link

      # print(All_pages_link)
      # print(All_pages_links)

# %%
# for i in z:
all_page_links_creator(z)
# All_pages_links=all_page_links_creator(z)

# %%
def all_page_included_creator(link):
  r=requests.get(link)
  soup=BeautifulSoup(r.content,'html5lib')
  c_link=soup.findAll("div",attrs={"class":"title"})
  for i in c_link:
    h=i.a.get("href")
    last_link=("{}{}".format("https://www.segabg.com",h))
    with open("/content/drive/MyDrive/bg_tr/sega_bg/sega_bg_all_links.txt", 'a') as file: 
       file.write(last_link+'\n')

# %%
# !cp '/content/sega_bg_all_links.txt' '/content/drive/MyDrive/bg_tr/sega_bg'

# %%
with open("sega_bg_all_links.txt") as file: 
   lines=[]
   for line in file:
        lines.append(line)
        print(line.split())

# %%
for i in lines:
  all_page_included_creator(i)

# %%
import time
import multiprocessing
import concurrent
import threading

# %%
t4=time.time()
# z=[]
with concurrent.futures.ProcessPoolExecutor() as execut:
  a_res=[execut.submit(all_page_included_creator,i)for i in lines]
  for f in concurrent.futures.as_completed(a_res):
    print(f.result())
  #   z.append(f.result())
    # if (f.result()!=None):
    #   z.append(f.result())

    # else : 
    #   print("geç")
print(time.time()-t4)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 758.9760222434998

# %%
for i in z:
  print(i)
# Out:
# None
# None
# None
# None
# None

# %%
sample=['https://www.segabg.com/category-observer?page=13',
'https://www.segabg.com/category-observer?page=14',
'https://www.segabg.com/category-observer?page=15']
for i in sample:
  all_page_included_creator(i)

# %%
def is_exist(link,c):
  #print(link)
  count=c
  r = requests.get(link)   
  soup = BeautifulSoup(r.content, 'html5lib')
  art=soup.findAll("div",attrs={"class":"article"}) 
  # print(count)
  if len(art)>1:
    if count<10:
      # print(count)
      count+=1
      new_link="{}{}".format(link[:-1],count)
      return is_exist(new_link,count)
    elif count<100:
      # print(count)
      count+=1
      new_link="{}{}".format(link[:-2],count)
      return is_exist(new_link,count)
    elif count<1000:
      # print(count)
      count+=1
      new_link="{}{}".format(link[:-3],count)
      return is_exist(new_link,count)
    # return True
  else:        
     return count-1
    
  
  # print(art)

# %%
h=is_exist(uus,166)
print(h)
# Out:
# https://www.segabg.com/category-observer?page=166
# https://www.segabg.com/category-observer?page=167
# https://www.segabg.com/category-observer?page=168
# 167

# %%
uus="https://www.segabg.com/category-observer?page=166"
page_count_finder(uus)
# Out:
# https://www.segabg.com/category-observer?page=161
# https://www.segabg.com/category-observer?page=162
# https://www.segabg.com/category-observer?page=163
# https://www.segabg.com/category-observer?page=164
# https://www.segabg.com/category-observer?page=165

# %%
z=headermenuitemfinder(uur)
for i in z:
  print(i)
# Out:
# https://www.segabg.com/category-observer?page=1
# https://www.segabg.com/category-bulgaria?page=1
# https://www.segabg.com/category-economy?page=1
# https://www.segabg.com/category-covid-19?page=1
# https://www.segabg.com/category-foreign-country?page=1
# https://www.segabg.com/category-culture?page=1
# https://www.segabg.com/category-education?page=1
# https://www.segabg.com/category-then?page=1
# https://www.segabg.com/category-zdrave?page=1
# https://www.segabg.com/category-cars?page=1
# https://www.segabg.com/category-movie-release?page=1
# https://www.segabg.com/category-consult?page=1
# https://www.segabg.com/category-media?page=1
# https://www.segabg.com/category-directory?page=1
# https://www.segabg.com/category-technologies?page=1
# https://www.segabg.com/category-observer?page=1

# %%
import bs4
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os
import urllib.request
import re
from pandas import DataFrame
import csv

# %%
def creator(link):
  inner_array=[]
  atxt=""  
  inner_array.append(link) 
  print(link)   
  r = requests.get(link)   
  soup = BeautifulSoup(r.content, 'html5lib')
  dat=soup.find("div",attrs={"class":"sega-article-date"})  
  datem=(dat.getText())
  print(datem)
  
  inner_array.append(datem)
  title=soup.find("h1",attrs={"class":"sega-title"}).getText()  
  print(title)
  inner_array.append(title)      
  table = soup.find("div", attrs = {"class":"sega-body"}).findAll('P')
  cable=soup.findAll("p")
  for j in cable[:-6]:
    if j!=" ":
      atxt+=j.getText().strip()
    else:
      print("yyyyy")
  # for i in table:
        # atxt+=i
  # print("---",atxt)
  inner_array.append(atxt)  
  ps=""
  with open("container_output.txt", 'a') as file: 
    #ps="{}{}{}{}{}{}{}".format(pdd[0],";",pdd[1],";",pdd[2],";",pdd[3])
    ps="{}{}{}{}{}{}{}".format(inner_array[0],";",inner_array[1],";",inner_array[2],";",inner_array[3])
    file.write(ps+'\n')
  return inner_array

# %%
# uur="https://www.segabg.com/category-observer/kak-vaksinirat-vuv-viena-ordnung-und-disziplin"
# creator(uur)
# Out:
# https://www.segabg.com/category-observer/kak-vaksinirat-vuv-viena-ordnung-und-disziplin
#  05 Юни 2021
#  Как ваксинират във Виена - с  Ordnung und Disziplin*
# ['https://www.segabg.com/category-observer/kak-vaksinirat-vuv-viena-ordnung-und-disziplin',
#  ' 05 Юни 2021 ',
#  ' Как ваксинират във Виена - с  Ordnung und Disziplin* ',
#  'Събота сутрин, Austria Center Vienna. Най-после е дошъл и моят ред за Covid-19 ваксина. Излизам от метростанцията и докато гледам в Google Maps маршрута към най-големия ваксинационен център във Виена, се натъквам на shuttle бусче, пуснато специално за целта. Електрическо, безплатно. Разстоянието е по-малко от 300 метра по права линия, но има възрастни хора, хора с увреждания, трудно подвижни... Помислено е за всеки. Удобно е за всеки.Пристигам на входа и виждам ОГРОМНО съоръжение, подготвено и функциониращо безупречно като часовников механизъм. Над 250 души работят тук всеки ден, някои от тях са готвачи, студенти, охранители, лаборанти, лекари. Всеки от тях има конкретна задача по веригата, а през тях ежедневно минават около 11 хил. души, като се очаква броят им да достигне 15 хил. в следващите дни.Проверяват часа ми на входа, после тръгвам по лъкатушещ коридор с различни спирки по пътя - на едно място проверяват документите ми, на друго вкарват нещо в системата, отбелязват ваксината във ваксинационния ми паспорт (малка жълта книжка, която в Австрия сякаш е задължителна). "Danke schön! / Bitte schön!" на всяка крачка, разбира се, защото - макар да обслужват хиляди хора ежедневно - всички служители от този многолюден персонал са учтиви и любезни и никой не демонстрира раздразнение, нито намеква, че му е под нивото да стои там с тая жилетка и да сочи посоката.Някъде по веригата едно момиче търпеливо ми обяснява на английски език, че малко по-надолу има квалифицарни лекари, които са там, за да ОТГОВАРЯТ на всички мои въпроси. След тях били самите кабинки за ваксините. Поглеждам скептично, но продължавам...... и наистина, няколко метра по-надолу следва шпалир от коктейлни масички с по две столчета пред всяка. На масичките седят лекари и очакват да спреш, да подпечатат книжката ти и да отговорят за всичко, което те вълнува - ще вдигнеш ли температура, има ли шанс да глътнеш чипа, как точно Бил Гейтс контролира милионите ваксинирани по света, излъчваш ли 5G след първата доза или чак след втората... ВСИЧКО, което ти хрумне. Преброих поне 10-15 лекари, които правеха САМО това. Отговаряха на въпроси.Стрелките ме водят най-сетне към кабинките. Две безкрайни редици кабинки, в които седят и търпеливо очакват следващия квалифицирани медицински работници. Самото бодване отне по-малко от половин минута, след което получих инструкции: "Изчакайте в залата 15 минути, преди да си тръгнете!".Изходът на самата кабинка води към просторно помещение, в което безупречно и през определено разстояние са подредени столчета. Сядаш и чакаш. Има екрани, които показват часа - да си гледаш и отброяваш минутите, ако искаш. Свири музичка. Да минава времето...15 минути по-късно показваш на служителя на изхода стикера в паспорта си и излизаш. Потребителското изживяване е приключило там, откъдето си тръгнал. Изходът и входът са на едно място.Над 250 служители, които работят по 12 часа ЕЖЕДНЕВНО. Огромно логистично упражнение, планирано и осъществено с прецизност, за да няма струпвания, да няма стрес, да няма излишни неприятни емоции. Така изглежда борбата с Ковид-19 в най-големия ваксинационен център. Само мога да гадая колко струва всичко това. И защо??? Защото ВСЕКИ ЧОВЕШКИ ЖИВОТ Е ЦЕНЕН! Защото само това е начинът да приключим с тая пандемия и животът да се нормализира. Така изглежда приоритизирането на здравето в държава, която се слави с една от най-добрите системи за здравеопазване в света. Това е РЕАЛНАТА БИТКА. Идиотщини от типа "Вирус няма!", "Това е просто грипче!", "Чипират ни, събудете се, овце!" просто нямат място в тази ситуация. Податливостта на фалшиви новини е за сметка на потърпевшите от това. Tut mir leid! (Съжалявам, нем.)Събота сутрин, Austria Center Vienna. Най-после е дошъл и моят ред за Covid-19 ваксина. Излизам от метростанцията и...----------------*Ordnung und Disziplin - ред и дисциплина, нем.**Публикуваме с позволението на автора. Текстът е от профила му във Фейсбук']

# %%
t4=time.time()
# z=[]
with concurrent.futures.ProcessPoolExecutor() as execut:
  a_res=[execut.submit(creator,i)for i in complete_links]
  for f in concurrent.futures.as_completed(a_res):
    print(f.result())
  #   z.append(f.result())
    # if (f.result()!=None):
    #   z.append(f.result())

    # else : 
    #   print("geç")
print(time.time()-t4)
